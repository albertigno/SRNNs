# %%
"""
@author: albertigno

"""

from MyLargeDataset import *
import torch, time, os

import torch.nn as nn
import torch.nn.functional as F

import networkx as nx

import matplotlib.pyplot as plt
from matplotlib.gridspec import GridSpec

print(torch.cuda.is_available())
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print (device)
# Out:
# True
# cuda:0

# %%
#os.environ['CUDA_VISIBLE_DEVICES'] = "3"
thresh = 0.3
lens = 0.25
decay = 0.3
num_classes = 20
batch_size = 256
learning_rate = 1e-4
#learning_rate = 2e-4
time_window = 100

dataset_path = r''

# %%
print(torch.cuda.is_available())
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print (device)
train_path = dataset_path+'/hd_digits/shd_train.h5'
test_path = dataset_path+'/hd_digits/shd_test.h5'
# load datasets
print("loading test set...")
test_dataset = MyDataset(test_path, 'hd_digits', time_window)
print("loading training set...")
train_dataset = MyDataset(train_path, 'hd_digits', time_window)
print("loading data with pytorch")
test_loader = torch.utils.data.DataLoader(dataset=test_dataset,
                                          batch_size=batch_size,
                                          shuffle=False, drop_last=True)

train_loader = torch.utils.data.DataLoader(dataset=train_dataset,
                                           batch_size=batch_size,
                                           shuffle=True, drop_last=True)
# Out:
# True
# cuda:0
# loading test set...
# ora si merito2
# torch.Size([2264, 100, 700])
# torch.Size([2264])
# torch.Size([2264, 100, 700]) torch.Size([2264, 20])
# loading training set...
# ora si merito2
# torch.Size([8156, 100, 700])
# torch.Size([8156])
# torch.Size([8156, 100, 700]) torch.Size([8156, 20])
# loading data with pytorch

# %%
class ActFun(torch.autograd.Function):

    @staticmethod
    def forward(ctx, input):
        ctx.save_for_backward(input)
        return input.gt(thresh).float()

    @staticmethod
    def backward(ctx, grad_output):
        input, = ctx.saved_tensors
        grad_input = grad_output.clone()
        temp = abs(input - thresh) < lens
        return grad_input * temp.float() / (2 * lens)

num_hidden = 128
num_output = 20

best_acc = 0
acc_record = list([])

class SNN_Model(nn.Module):

    def __init__(self, num_classes=20):
        super(SNN_Model, self).__init__()
        
        self.fc_ih = nn.Linear(700, num_hidden, bias= False)
        self.fc_hh = nn.Linear(num_hidden, num_hidden, bias= False)
        self.fc_ho = nn.Linear(num_hidden, num_output, bias= False)
        
        self.dropout = nn.Dropout(p=0.2, inplace=False)
        
        
    def forward(self, input, win):
        
        h0_mem = h0_spike = h0_sumspike = torch.zeros(1, batch_size, num_hidden, device=device)
        h2_mem = h2_spike = h2_sumspike = torch.zeros(1, batch_size, num_output, device=device)
        
        dense_input = input.to_dense()
        dense_input = 1*(dense_input > 0).float()
        
        for step in range(win):
            
            x = dense_input[:, step, :]
            x = x.view(1, batch_size, -1)
            
            #x = self.dropout(x)

            h0_mem, h0_spike = mem_update_rnn(self.fc_ih, self.fc_hh, x, h0_spike, h0_mem, h0_spike)
            
            #h0_spike = self.dropout(h0_spike)
                        
            h2_mem, h2_spike = mem_update(self.fc_ho, h0_spike, h2_mem, h2_spike)

            h2_sumspike += h2_spike
        
        outputs = h2_sumspike / (win)
        
        return outputs[0]    
    
    
def mem_update(operation, x, mem, spike):
    mem = mem * decay * (1 - spike) + operation(x)
    spike = act_fun(mem)
    mem = mem*(mem<thresh)
    return mem, spike

def mem_update_rnn(operation1, operation2, x, h, mem, spike):
    a = operation1(x)
    b = operation2(h)
    c = mem * decay * (1 - spike) 
    mem = a + b + c
    spike = act_fun(mem)
    mem = mem*(mem<thresh)
    return mem, spike

# %%
snn = SNN_Model()

num_epochs = 100

wsw = snn.fc_hh.weight.data
modelname = 'heidelberg_rnn_{}.t7'.format(num_hidden)

plt.figure()
plt.subplot(121); plt.imshow(w0, cmap = 'seismic')
#plt.subplot(122); plt.imshow(snn.fc_hh.weight.data.cpu(), cmap = 'seismic')

plt.savefig('./checkpoint/weights_{}.png'.format(num_hidden))
    
snn.to(device)

criterion = nn.MSELoss()

def lr_scheduler(optimizer, epoch, init_lr=0.1, lr_decay_epoch=100):
    """Decay learning rate by a factor of 0.1 every lr_decay_epoch epochs."""

    if epoch % lr_decay_epoch == 0 and epoch > 1:
        for param_group in optimizer.param_groups:
            param_group['lr'] = param_group['lr'] * 0.98

    return optimizer

optimizer = torch.optim.Adam(snn.parameters(), lr=learning_rate)

act_fun = ActFun.apply
print(modelname)
# Out:
# heidelberg_rnn_128.t7

# %%
win = 50
best_acc = 0
train_loss = []
test_loss = []

if not os.path.isdir('checkpoint'):
    os.mkdir('checkpoint')

for epoch in range(num_epochs):
    running_loss = 0
    total_loss_train = 0
    start_time = time.time()
    total = 0
    
    for i, (images, labels) in enumerate(train_loader):
        
        snn.zero_grad()
        optimizer.zero_grad()

        images = images.float().to(device)
        labels = labels.float().to(device)
        outputs = snn(images, win)
        loss = criterion(outputs, labels)
        running_loss += loss.item()
        total_loss_train += loss.item()
        total += labels.size(0)
        loss.backward()
        optimizer.step()
        if (i + 1) % 50 == 0:
            # print( outputs.sum(dim=0) )
            print('Epoch [%d/%d], Step [%d/%d], Loss: %.5f'
                  % (epoch + 1, num_epochs, i + 1, len(train_dataset) // batch_size, running_loss))
            running_loss = 0
            print('Time elasped:', time.time() - start_time)
    train_loss.append(total_loss_train / total)
    
    optimizer = lr_scheduler(optimizer, epoch, learning_rate, 1)
    
    correct = 0
    total = 0
    total_loss_test = 0
    for images, labels in test_loader:
        images = images.float().to(device)
        labels = labels.float().to(device)
        outputs = snn(images, win)
        loss = criterion(outputs, labels)
        _, predicted = torch.max(outputs.data, 1)
        _, reference = torch.max(labels.data, 1)
        total += labels.size(0)
        correct += (predicted == reference).sum()
        total_loss_test += loss.item() 

    print('Iters:', epoch, '\n\n\n')
    print('Test Accuracy of the model on the test samples: %.3f' % (100 * correct.float() / total))
    
    print('Train loss: {}, Test loss: {}'.format(total_loss_train, total_loss_test))
    
    acc = 100. * float(correct) / float(total)
    acc_record.append(acc)
    
    test_loss.append(total_loss_test / total)
    state = {
    'net': snn.state_dict(),
    'acc': acc,
    'epoch': epoch,
    'acc_record': acc_record,
    'train_loss': train_loss,
    'test_loss': test_loss
    }    
    
    if acc>best_acc:
        print('Saving best accuracy so far..')
        print(acc)
        torch.save(state, './checkpoint/' + modelname,  _use_new_zipfile_serialization=False)
        best_acc = acc
# Out:
# Iters: 0
#
#
#
# Test Accuracy of the model on the test samples: 8.838
# Train loss: 1.5803408063948154, Test loss: 0.38652797788381577
# Saving best accuracy so far..
# 8.837890625
# Iters: 1
#
#
#
# Test Accuracy of the model on the test samples: 12.451
# Train loss: 1.4825989305973053, Test loss: 0.3785381317138672
# Saving best accuracy so far..
# 12.451171875
# Iters: 2
#
#
#
# Test Accuracy of the model on the test samples: 19.678
# Train loss: 1.441270723938942, Test loss: 0.36670664697885513
# Saving best accuracy so far..
# 19.677734375
# Iters: 3
#
#
#
# Test Accuracy of the model on the test samples: 24.658
# Train loss: 1.4051301144063473, Test loss: 0.35958540067076683
# Saving best accuracy so far..
# 24.658203125
# Iters: 4
#
#
#
# Test Accuracy of the model on the test samples: 25.488
# Train loss: 1.377485815435648, Test loss: 0.3556536026299
# Saving best accuracy so far..
# 25.48828125
# Iters: 5
#
#
#
# Test Accuracy of the model on the test samples: 26.807
# Train loss: 1.3507224582135677, Test loss: 0.3489513359963894
# Saving best accuracy so far..
# 26.806640625
# Iters: 6
#
#
#
# Test Accuracy of the model on the test samples: 28.369
# Train loss: 1.3304581604897976, Test loss: 0.34411758184432983
# Saving best accuracy so far..
# 28.369140625
# Iters: 7
#
#
#
# Test Accuracy of the model on the test samples: 29.785
# Train loss: 1.305606048554182, Test loss: 0.3396994508802891
# Saving best accuracy so far..
# 29.78515625
# Iters: 8
#
#
#
# Test Accuracy of the model on the test samples: 32.910
# Train loss: 1.2835576795041561, Test loss: 0.3342521972954273
# Saving best accuracy so far..
# 32.91015625
# Iters: 9
#
#
#
# Test Accuracy of the model on the test samples: 36.670
# Train loss: 1.2598377540707588, Test loss: 0.32846806198358536
# Saving best accuracy so far..
# 36.669921875
# Iters: 10
#
#
#
# Test Accuracy of the model on the test samples: 40.137
# Train loss: 1.240774791687727, Test loss: 0.3192770443856716
# Saving best accuracy so far..
# 40.13671875
# Iters: 11
#
#
#
# Test Accuracy of the model on the test samples: 40.527
# Train loss: 1.2095820754766464, Test loss: 0.313536886125803
# Saving best accuracy so far..
# 40.52734375
# Iters: 12
#
#
#
# Test Accuracy of the model on the test samples: 43.408
# Train loss: 1.1799280941486359, Test loss: 0.3057982884347439
# Saving best accuracy so far..
# 43.408203125
# Iters: 13
#
#
#
# Test Accuracy of the model on the test samples: 43.994
# Train loss: 1.1566576436161995, Test loss: 0.30062923207879066
# Saving best accuracy so far..
# 43.994140625
# Iters: 14
#
#
#
# Test Accuracy of the model on the test samples: 44.092
# Train loss: 1.1359993517398834, Test loss: 0.2951679043471813
# Saving best accuracy so far..
# 44.091796875
# Iters: 15
#
#
#
# Test Accuracy of the model on the test samples: 44.922
# Train loss: 1.111543696373701, Test loss: 0.29192085936665535
# Saving best accuracy so far..
# 44.921875
# Iters: 16
#
#
#
# Test Accuracy of the model on the test samples: 47.119
# Train loss: 1.1026975959539413, Test loss: 0.28844259306788445
# Saving best accuracy so far..
# 47.119140625
# Iters: 17
#
#
#
# Test Accuracy of the model on the test samples: 47.510
# Train loss: 1.086093932390213, Test loss: 0.2869248539209366
# Saving best accuracy so far..
# 47.509765625
# Iters: 18
#
#
#
# Test Accuracy of the model on the test samples: 47.900
# Train loss: 1.0695968233048916, Test loss: 0.2834725081920624
# Saving best accuracy so far..
# 47.900390625
# Iters: 19
#
#
#
# Test Accuracy of the model on the test samples: 48.486
# Train loss: 1.0561938658356667, Test loss: 0.2814331278204918
# Saving best accuracy so far..
# 48.486328125
# Iters: 20
#
#
#
# Test Accuracy of the model on the test samples: 51.855
# Train loss: 1.074873685836792, Test loss: 0.27930086851119995
# Saving best accuracy so far..
# 51.85546875
# Iters: 21
#
#
#
# Test Accuracy of the model on the test samples: 49.902
# Train loss: 1.0413376949727535, Test loss: 0.2768142372369766
# Iters: 22
#
#
#
# Test Accuracy of the model on the test samples: 51.318
# Train loss: 1.0288697853684425, Test loss: 0.2770141512155533
# Iters: 23
#
#
#
# Test Accuracy of the model on the test samples: 51.367
# Train loss: 1.0291048884391785, Test loss: 0.2746659405529499
# Iters: 24
#
#
#
# Test Accuracy of the model on the test samples: 50.635
# Train loss: 1.0093030855059624, Test loss: 0.2758934423327446
# Iters: 25
#
#
#
# Test Accuracy of the model on the test samples: 50.781
# Train loss: 1.0150223895907402, Test loss: 0.2740122638642788
# Iters: 26
#
#
#
# Test Accuracy of the model on the test samples: 53.320
# Train loss: 0.9975483138114214, Test loss: 0.2706779018044472
# Saving best accuracy so far..
# 53.3203125
# Iters: 27
#
#
#
# Test Accuracy of the model on the test samples: 53.613
# Train loss: 0.9988517314195633, Test loss: 0.2682950161397457
# Saving best accuracy so far..
# 53.61328125
# Iters: 28
#
#
#
# Test Accuracy of the model on the test samples: 51.514
# Train loss: 1.000095959752798, Test loss: 0.27293726801872253
# Iters: 29
#
#
#
# Test Accuracy of the model on the test samples: 49.609
# Train loss: 0.9816456604748964, Test loss: 0.27155859395861626
# Iters: 30
#
#
#
# Test Accuracy of the model on the test samples: 51.660
# Train loss: 0.9748005028814077, Test loss: 0.2708887569606304
# Iters: 31
#
#
#
# Test Accuracy of the model on the test samples: 53.516
# Train loss: 0.9698190148919821, Test loss: 0.2672586850821972
# Iters: 32
#
#
#
# Test Accuracy of the model on the test samples: 52.246
# Train loss: 0.9608741663396358, Test loss: 0.26711946353316307
# Iters: 33
#
#
#
# Test Accuracy of the model on the test samples: 52.832
# Train loss: 0.9479243084788322, Test loss: 0.2659278176724911
# Iters: 34
#
#
#
# Test Accuracy of the model on the test samples: 52.539
# Train loss: 0.9526276122778654, Test loss: 0.26560407504439354
# Iters: 35
#
#
#
# Test Accuracy of the model on the test samples: 53.516
# Train loss: 0.9462216682732105, Test loss: 0.26378946006298065
# Iters: 36
#
#
#
# Test Accuracy of the model on the test samples: 54.883
# Train loss: 0.9389105588197708, Test loss: 0.2620807867497206
# Saving best accuracy so far..
# 54.8828125
# Iters: 37
#
#
#
# Test Accuracy of the model on the test samples: 53.516
# Train loss: 0.9408378563821316, Test loss: 0.2647886071354151
# Iters: 38
#
#
#
# Test Accuracy of the model on the test samples: 56.348
# Train loss: 0.934562299400568, Test loss: 0.2601099293678999
# Saving best accuracy so far..
# 56.34765625
# Iters: 39
#
#
#
# Test Accuracy of the model on the test samples: 53.467
# Train loss: 0.9255614243447781, Test loss: 0.26360398903489113
# Iters: 40
#
#
#
# Test Accuracy of the model on the test samples: 53.125
# Train loss: 0.9273058865219355, Test loss: 0.2641552444547415
# Iters: 41
#
#
#
# Test Accuracy of the model on the test samples: 54.980
# Train loss: 0.9160625319927931, Test loss: 0.2599828951060772
# Iters: 42
#
#
#
# Test Accuracy of the model on the test samples: 54.834
# Train loss: 0.9096984658390284, Test loss: 0.25914797373116016
# Iters: 43
#
#
#
# Test Accuracy of the model on the test samples: 54.053
# Train loss: 0.9074408002197742, Test loss: 0.2632003240287304
# Iters: 44
#
#
#
# Test Accuracy of the model on the test samples: 54.688
# Train loss: 0.90516696870327, Test loss: 0.25825454108417034
# Iters: 45
#
#
#
# Test Accuracy of the model on the test samples: 53.662
# Train loss: 0.8988243956118822, Test loss: 0.26007179915905
# Iters: 46
#
#
#
# Test Accuracy of the model on the test samples: 55.322
# Train loss: 0.9066107347607613, Test loss: 0.2599564902484417
# Iters: 47
#
#
#
# Test Accuracy of the model on the test samples: 56.689
# Train loss: 0.8899273760616779, Test loss: 0.2558658644556999
# Saving best accuracy so far..
# 56.689453125
# Iters: 48
#
#
#
# Test Accuracy of the model on the test samples: 56.445
# Train loss: 0.8890279121696949, Test loss: 0.25420461781322956
# Iters: 49
#
#
#
# Test Accuracy of the model on the test samples: 55.225
# Train loss: 0.8840320464223623, Test loss: 0.2555086761713028
# Iters: 50
#
#
#
# Test Accuracy of the model on the test samples: 56.592
# Train loss: 0.8779856581240892, Test loss: 0.25311547704041004
# Iters: 51
#
#
#
# Test Accuracy of the model on the test samples: 54.102
# Train loss: 0.874064089730382, Test loss: 0.2586900219321251
# Iters: 52
#
#
#
# Test Accuracy of the model on the test samples: 56.348
# Train loss: 0.8716498669236898, Test loss: 0.2565476596355438
# Iters: 53
#
#
#
# Test Accuracy of the model on the test samples: 55.908
# Train loss: 0.8710951097309589, Test loss: 0.25378234311938286
# Iters: 54
#
#
#
# Test Accuracy of the model on the test samples: 55.615
# Train loss: 0.866058612242341, Test loss: 0.2541271075606346
# Iters: 55
#
#
#
# Test Accuracy of the model on the test samples: 56.641
# Train loss: 0.8676832243800163, Test loss: 0.25151523388922215
# Iters: 56
#
#
#
# Test Accuracy of the model on the test samples: 57.178
# Train loss: 0.8620460387319326, Test loss: 0.2532098609954119
# Saving best accuracy so far..
# 57.177734375
# Iters: 57
#
#
#
# Test Accuracy of the model on the test samples: 57.861
# Train loss: 0.8566159643232822, Test loss: 0.25080304965376854
# Saving best accuracy so far..
# 57.861328125
# Iters: 58
#
#
#
# Test Accuracy of the model on the test samples: 57.520
# Train loss: 0.8541227504611015, Test loss: 0.24997922964394093
# Iters: 59
#
#
#
# Test Accuracy of the model on the test samples: 57.910
# Train loss: 0.8546803910285234, Test loss: 0.24932149425148964
# Saving best accuracy so far..
# 57.91015625
# Iters: 60
#
#
#
# Test Accuracy of the model on the test samples: 58.203
# Train loss: 0.8491886965930462, Test loss: 0.2495395392179489
# Saving best accuracy so far..
# 58.203125
# Iters: 61
#
#
#
# Test Accuracy of the model on the test samples: 54.248
# Train loss: 0.8823122102767229, Test loss: 0.2559651657938957
# Iters: 62
#
#
#
# Test Accuracy of the model on the test samples: 55.908
# Train loss: 0.8559273052960634, Test loss: 0.25221570767462254
# Iters: 63
#
#
#
# Test Accuracy of the model on the test samples: 57.422
# Train loss: 0.8359945546835661, Test loss: 0.2506757080554962
# Iters: 64
#
#
#
# Test Accuracy of the model on the test samples: 58.252
# Train loss: 0.8370646294206381, Test loss: 0.24884133040905
# Saving best accuracy so far..
# 58.251953125
# Iters: 65
#
#
#
# Test Accuracy of the model on the test samples: 55.371
# Train loss: 0.840991897508502, Test loss: 0.2536934409290552
# Iters: 66
#
#
#
# Test Accuracy of the model on the test samples: 57.373
# Train loss: 0.8359258770942688, Test loss: 0.2500790748745203
# Iters: 67
#
#
#
# Test Accuracy of the model on the test samples: 56.494
# Train loss: 0.8305640146136284, Test loss: 0.24909399263560772
# Iters: 68
#
#
#
# Test Accuracy of the model on the test samples: 57.666
# Train loss: 0.8292401842772961, Test loss: 0.2478459421545267
# Iters: 69
#
#
#
# Test Accuracy of the model on the test samples: 58.936
# Train loss: 0.8323933724313974, Test loss: 0.24857227317988873
# Saving best accuracy so far..
# 58.935546875
# Iters: 70
#
#
#
# Test Accuracy of the model on the test samples: 56.982
# Train loss: 0.8280220534652472, Test loss: 0.24957000836730003
# Iters: 71
#
#
#
# Test Accuracy of the model on the test samples: 59.570
# Train loss: 0.8243409637361765, Test loss: 0.24679789692163467
# Saving best accuracy so far..
# 59.5703125
# Iters: 72
#
#
#
# Test Accuracy of the model on the test samples: 58.301
# Train loss: 0.8254241701215506, Test loss: 0.2452226597815752
# Iters: 73
#
#
#
# Test Accuracy of the model on the test samples: 57.764
# Train loss: 0.8244893103837967, Test loss: 0.24799852445721626
# Iters: 74
#
#
#
# Test Accuracy of the model on the test samples: 59.570
# Train loss: 0.8184427488595247, Test loss: 0.24405227042734623
# Iters: 75
#
#
#
# Test Accuracy of the model on the test samples: 58.545
# Train loss: 0.8134586941450834, Test loss: 0.24384921975433826
# Iters: 76
#
#
#
# Test Accuracy of the model on the test samples: 58.643
# Train loss: 0.8133274540305138, Test loss: 0.24630673229694366
# Iters: 77
#
#
#
# Test Accuracy of the model on the test samples: 59.375
# Train loss: 0.8135069701820612, Test loss: 0.24450250156223774
# Iters: 78
#
#
#
# Test Accuracy of the model on the test samples: 59.033
# Train loss: 0.8115033768117428, Test loss: 0.2444600835442543
# Iters: 79
#
#
#
# Test Accuracy of the model on the test samples: 60.352
# Train loss: 0.8092117309570312, Test loss: 0.24292898923158646
# Saving best accuracy so far..
# 60.3515625
# Iters: 80
#
#
#
# Test Accuracy of the model on the test samples: 59.814
# Train loss: 0.816063079982996, Test loss: 0.24515953287482262
# Iters: 81
#
#
#
# Test Accuracy of the model on the test samples: 58.984
# Train loss: 0.8129598647356033, Test loss: 0.24501766823232174
# Iters: 82
#
#
#
# Test Accuracy of the model on the test samples: 59.180
# Train loss: 0.8046727627515793, Test loss: 0.2451559454202652
# Iters: 83
#
#
#
# Test Accuracy of the model on the test samples: 58.643
# Train loss: 0.8010572083294392, Test loss: 0.2455442976206541
# Iters: 84
#
#
#
# Test Accuracy of the model on the test samples: 59.570
# Train loss: 0.8045886233448982, Test loss: 0.24324813671410084
# Iters: 85
#
#
#
# Test Accuracy of the model on the test samples: 59.033
# Train loss: 0.8017378970980644, Test loss: 0.24428570084273815
# Iters: 86
#
#
#
# Test Accuracy of the model on the test samples: 58.496
# Train loss: 0.8037003427743912, Test loss: 0.24510852620005608
# Iters: 87
#
#
#
# Test Accuracy of the model on the test samples: 59.766
# Train loss: 0.8018303252756596, Test loss: 0.24271492287516594
# Iters: 88
#
#
#
# Test Accuracy of the model on the test samples: 57.764
# Train loss: 0.7965032197535038, Test loss: 0.2487183716148138
# Iters: 89
#
#
#
# Test Accuracy of the model on the test samples: 59.814
# Train loss: 0.8031505700200796, Test loss: 0.24409985356032848
# Iters: 90
#
#
#
# Test Accuracy of the model on the test samples: 60.596
# Train loss: 0.7983070444315672, Test loss: 0.2423455659300089
# Saving best accuracy so far..
# 60.595703125
# Iters: 91
#
#
#
# Test Accuracy of the model on the test samples: 60.107
# Train loss: 0.8051209580153227, Test loss: 0.24152946658432484
# Iters: 92
#
#
#
# Test Accuracy of the model on the test samples: 58.594
# Train loss: 0.7980527617037296, Test loss: 0.24175492487847805
# Iters: 93
#
#
#
# Test Accuracy of the model on the test samples: 59.912
# Train loss: 0.7995250262320042, Test loss: 0.24356633238494396
# Iters: 94
#
#
#
# Test Accuracy of the model on the test samples: 59.033
# Train loss: 0.7921829931437969, Test loss: 0.24524915404617786
# Iters: 95
#
#
#
# Test Accuracy of the model on the test samples: 59.668
# Train loss: 0.7916887700557709, Test loss: 0.2415030561387539
# Iters: 96
#
#
#
# Test Accuracy of the model on the test samples: 59.375
# Train loss: 0.7856963537633419, Test loss: 0.2408277429640293
# Iters: 97
#
#
#
# Test Accuracy of the model on the test samples: 59.375
# Train loss: 0.789886886253953, Test loss: 0.2417419571429491
# Iters: 98
#
#
#
# Test Accuracy of the model on the test samples: 60.986
# Train loss: 0.7902120538055897, Test loss: 0.24006141535937786
# Saving best accuracy so far..
# 60.986328125
# Iters: 99
#
#
#
# Test Accuracy of the model on the test samples: 59.766
# Train loss: 0.7924070544540882, Test loss: 0.24115476943552494

# %%
state = {
'net': snn.state_dict(),
'acc': acc,
    
    
    
'epoch': epoch,
'acc_record': acc_record,
'train_loss': train_loss,
'test_loss': test_loss
}    

mf = modelname.split('.')[0] + '_final.t7'
torch.save(state, './checkpoint/' + mf ,  _use_new_zipfile_serialization=False)

# %%
import matplotlib.pyplot as plt
plt.plot(train_loss)
plt.plot(test_loss)

# %%
import matplotlib.pyplot as plt
plt.plot(train_loss)
plt.plot(test_loss)

# %%
def get_accuracy(model):
    correct = 0
    total = 0
    for images, labels in test_loader:
        images = images.float().to(device)
        outputs = model(images, win)
        _, predicted = torch.max(outputs.data, 1)
        _, labels = torch.max(labels.data, 1)
        total += labels.size(0)
        correct += (predicted.cpu() == labels).sum()
    
    acc = 100 * correct.float() / total
    return acc

acc = get_accuracy(model)

print('Test Accuracy of the model on the 10000 test images: %.3f' % (acc))
# Out:
# Test Accuracy of the model on the 10000 test images: 70.264

# %%
import torch
import numpy as np
import os

print("loading trained model")
model_to_load = modelname

#snn_state_dict = torch.load('./checkpoint/'+modelname, map_location=torch.device('cpu'))['net']
snn_state_dict = torch.load('./checkpoint/'+model_to_load, map_location=torch.device('cpu'))['net']
print(snn_state_dict.keys())

layers_location = 'checkpoint/'+model_to_load.split('.')[0]

if not os.path.isdir(layers_location):
    os.mkdir(layers_location)

weights_biases = []
for k in snn_state_dict:
    np.savez(layers_location+'/'+k,snn_state_dict[k].data.cpu().numpy())
    weights_biases.append(snn_state_dict[k].data.cpu().numpy())
# Out:
# loading trained model
# odict_keys(['fc_ih.weight', 'fc_hh.weight', 'fc_ho.weight'])

# %%
model_to_load = modelname
#model_to_load = 'heidelberg_rnn_400_mem1.t7'
snn_state_dict = torch.load('./checkpoint/'+model_to_load, map_location=torch.device('cpu'))['net']

model = SNN_Model()
model.load_state_dict(snn_state_dict)
model.to(device)
model.eval()

num_to_test = 50
for images, labels in test_loader:
    images = images.float().to(device)
    labels = labels.float().to(device)
    outputs = model(images, win)
    _, predicted = torch.max(outputs[:num_to_test,:].data, 1)
    _, reference = torch.max(labels[:num_to_test,:].data, 1)
    correct = (predicted == reference).sum()
    break

print('Test Accuracy of the model on the 10000 test images: %.3f' % (100 * correct.float() / num_to_test))
# Out:
# Test Accuracy of the model on the 10000 test images: 66.000

# %% [markdown]
# #### SpiNNaker: 50 muestras, 58%
