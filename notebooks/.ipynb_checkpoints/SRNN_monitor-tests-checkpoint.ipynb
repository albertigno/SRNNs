# %%
"""
@author: albertigno

"""

from DatasetLoader import *
import torch, time, os
import torch.nn as nn
import torch.nn.functional as F
#import networkx as nx
import matplotlib.pyplot as plt
#from matplotlib.gridspec import GridSpec

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
#device = 'cpu'
print ('Running on: {}'.format(device))

dataset = 'shd'
dataset_path = r'./../../datasets'
thresh = 0.3

if dataset == 'shd':
    batch_size = 256 # default 256
    learning_rate = 1e-4 # default 1e-4
    time_window = 50 # shd 50, nmnist 25-30
    #time_window = 100
    train_path = dataset_path+'/shd_digits/shd_train.h5'
    test_path = dataset_path+'/shd_digits/shd_test.h5'
else:
    batch_size = 40 
    learning_rate = 1e-4
    time_window = 25     
    train_path = dataset_path+'/nmnist/nmnist_train.mat'
    test_path = dataset_path+'/nmnist/nmnist_test.mat'
# Out:
# Running on: cuda:0

# %%
from snn_models_monitor import *
# %load_ext autoreload
# %autoreload 1
# %aimport snn_models_monitor

#tau_m = 'adp'
tau_m = 0.8305
#snn = RSNN_delay(d='shd', num_hidden=128, thresh=0.3, decay=0.3, batch_size=batch_size, win=50, device=device)
#snn = RSNN_monitor('shd', num_hidden=512, thresh=0.3, tau_m=tau_m, batch_size=batch_size, win=time_window, device=device)
snn = RSNN_monitor(dataset, num_hidden=256, thresh=0.3, tau_m=tau_m, batch_size=batch_size, win=time_window, device=device)
snn.to(device)

snn.train_step(train_loader, optimizer=optimizer, criterion=nn.MSELoss(), num_samples = num_samples, spkreg=0.01)
snn.test(test_loader, criterion=nn.MSELoss())
snn.save_to_numpy(modelname[:-3])
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# RSNN_monitor(
#   (fc_ih): Linear(in_features=700, out_features=256, bias=False)
#   (fc_hh): Linear(in_features=256, out_features=256, bias=False)
#   (fc_ho): Linear(in_features=256, out_features=20, bias=False)
#   (i_drop): Dropout(p=0.1, inplace=False)
# )

# %%
snn.plot_weights('hh')
# Out:
# <AxesSubplot:title={'center':'hidden-to-hidden weight distribution'}, xlabel='weight', ylabel='frequency'>

# %%
# load datasets
print("loading test set...")
test_dataset = DatasetLoader(test_path, dataset, time_window, 'cpu')
print("loading training set...")
train_dataset = DatasetLoader(train_path, dataset, time_window, device)
print("loading data with pytorch")
test_loader = torch.utils.data.DataLoader(dataset=test_dataset,
                                          batch_size=batch_size,
                                          shuffle=False, drop_last=True)

train_loader = torch.utils.data.DataLoader(dataset=train_dataset,
                                           batch_size=batch_size,
                                           shuffle=True, drop_last=True)
# Out:
# loading test set...
# num sample: 2264
# torch.Size([2264, 50, 700]) torch.Size([2264, 20])
# loading training set...
# num sample: 8156
# torch.Size([8156, 50, 700]) torch.Size([8156, 20])
# loading data with pytorch

# %%
# check density of input spikes 
input_spike = test_dataset.images.reshape(-1, test_dataset.images.shape[-1]).sum(axis=1).cpu().numpy()
print([input_spike.max(), input_spike.mean()])
i_s = input_spike[:1000]
t = len(i_s)
plt.figure()
plt.plot(i_s)
plt.plot(np.arange(t), input_spike.max()*np.ones(t))
plt.plot(np.arange(t), input_spike.mean()*np.ones(t))
plt.show()
# Out:
# [519.0, 110.765625]

# %%
# training configuration

num_epochs = 200
modelname = dataset+'_rnn_{}.t7'.format(snn.num_hidden, tau_m)
num_samples = train_dataset.images.size()[0]

#optimizer = torch.optim.Adam(snn.parameters(), lr=learning_rate)

# set different learning rates
base_params = [snn.fc_ih.weight,
               snn.fc_hh.weight,
               snn.fc_ho.weight, 
               ]
if tau_m=='adp':
    print('tau_m_h ')
    optimizer = torch.optim.Adam([
        {'params': base_params},
        {'params': snn.tau_m_h, 'lr': learning_rate * 10.0}],
        lr=learning_rate)
else:    
    optimizer = torch.optim.Adam([
        {'params': base_params}],
        lr=learning_rate)
    
act_fun = ActFun.apply
print(modelname)
# Out:
# shd_rnn_256.t7

# %%
# training loop
taus_m = []
for epoch in range(num_epochs):
    print('Epoch [%d/%d]'  % (epoch + 1, num_epochs))
    start_time = time.time()
    snn.train_step(train_loader, optimizer=optimizer, criterion=nn.MSELoss(), num_samples = num_samples, spkreg=0.01)
    print('Time elasped:', time.time() - start_time)
    
    # update learning rate
    optimizer = snn.lr_scheduler(optimizer, lr_decay_epoch=1)
    
    # weight and decay recording
    taus_m.append((snn.tau_m_h.data.detach().clone(), snn.tau_m_o.data.detach().clone()))
    
    if (epoch + 1) % 5 == 0:
        snn.test(test_loader, criterion=nn.MSELoss())
        snn.save_model(modelname)
# Out:
# Epoch [1/200]
# Step [10/31], Loss: 0.50910
# Step [20/31], Loss: 0.48989
# Step [30/31], Loss: 0.48232
# Time elasped: 2.9832589626312256
# Epoch [2/200]
# Step [10/31], Loss: 0.47064
# Step [20/31], Loss: 0.46389
# Step [30/31], Loss: 0.45691
# Time elasped: 2.3935086727142334
# Epoch [3/200]
# Step [10/31], Loss: 0.45126
# Step [20/31], Loss: 0.44482
# Step [30/31], Loss: 0.44241
# Time elasped: 2.3870351314544678
# Epoch [4/200]
# Step [10/31], Loss: 0.43648
# Step [20/31], Loss: 0.43097
# Step [30/31], Loss: 0.43135
# Time elasped: 2.4011342525482178
# Epoch [5/200]
# Step [10/31], Loss: 0.42491
# Step [20/31], Loss: 0.42294
# Step [30/31], Loss: 0.41678
# Time elasped: 2.3851478099823
# avg spk_count per neuron for all 50 timesteps 5.5499114990234375
# Test Accuracy of the model on the test samples: 38.965
# Epoch [6/200]
# Step [10/31], Loss: 0.41281
# Step [20/31], Loss: 0.41122
# Step [30/31], Loss: 0.40542
# Time elasped: 2.436264753341675
# Epoch [7/200]
# Step [10/31], Loss: 0.40042
# Step [20/31], Loss: 0.39556
# Step [30/31], Loss: 0.38964
# Time elasped: 2.4180288314819336
# Epoch [8/200]
# Step [10/31], Loss: 0.38151
# Step [20/31], Loss: 0.37734
# Step [30/31], Loss: 0.37788
# Time elasped: 2.4143717288970947
# Epoch [9/200]
# Step [10/31], Loss: 0.36891
# Step [20/31], Loss: 0.36858
# Step [30/31], Loss: 0.37180
# Time elasped: 2.416141986846924
# Epoch [10/200]
# Step [10/31], Loss: 0.36943
# Step [20/31], Loss: 0.36253
# Step [30/31], Loss: 0.35808
# Time elasped: 2.4090325832366943
# avg spk_count per neuron for all 50 timesteps 8.756591796875
# Test Accuracy of the model on the test samples: 51.367
# Epoch [11/200]
# Step [10/31], Loss: 0.34925
# Step [20/31], Loss: 0.34867
# Step [30/31], Loss: 0.35306
# Time elasped: 2.4407830238342285
# Epoch [12/200]
# Step [10/31], Loss: 0.34271
# Step [20/31], Loss: 0.34677
# Step [30/31], Loss: 0.34064
# Time elasped: 2.418215751647949
# Epoch [13/200]
# Step [10/31], Loss: 0.33948
# Step [20/31], Loss: 0.34074
# Step [30/31], Loss: 0.33078
# Time elasped: 2.412231206893921
# Epoch [14/200]
# Step [10/31], Loss: 0.32780
# Step [20/31], Loss: 0.32458
# Step [30/31], Loss: 0.32977
# Time elasped: 2.416426658630371
# Epoch [15/200]
# Step [10/31], Loss: 0.32039
# Step [20/31], Loss: 0.32685
# Step [30/31], Loss: 0.32675
# Time elasped: 2.4190280437469482
# avg spk_count per neuron for all 50 timesteps 10.387481689453125
# Test Accuracy of the model on the test samples: 54.785
# Epoch [16/200]
# Step [10/31], Loss: 0.31819
# Step [20/31], Loss: 0.31695
# Step [30/31], Loss: 0.31408
# Time elasped: 2.4369022846221924
# Epoch [17/200]
# Step [10/31], Loss: 0.31711
# Step [20/31], Loss: 0.31102
# Step [30/31], Loss: 0.30321
# Time elasped: 2.419212579727173
# Epoch [18/200]
# Step [10/31], Loss: 0.30608
# Step [20/31], Loss: 0.30235
# Step [30/31], Loss: 0.29965
# Time elasped: 2.4191362857818604
# Epoch [19/200]
# Step [10/31], Loss: 0.30285
# Step [20/31], Loss: 0.30517
# Step [30/31], Loss: 0.33155
# Time elasped: 2.4514267444610596
# Epoch [20/200]
# Step [10/31], Loss: 0.32300
# Step [20/31], Loss: 0.30373
# Step [30/31], Loss: 0.30209
# Time elasped: 2.417947292327881
# avg spk_count per neuron for all 50 timesteps 10.813262939453125
# Test Accuracy of the model on the test samples: 57.520
# Epoch [21/200]
# Step [10/31], Loss: 0.29347
# Step [20/31], Loss: 0.29426
# Step [30/31], Loss: 0.29435
# Time elasped: 2.4349205493927
# Epoch [22/200]
# Step [10/31], Loss: 0.28701
# Step [20/31], Loss: 0.28658
# Step [30/31], Loss: 0.29448
# Time elasped: 2.427973508834839
# Epoch [23/200]
# Step [10/31], Loss: 0.28028
# Step [20/31], Loss: 0.28088
# Step [30/31], Loss: 0.28851
# Time elasped: 2.4282305240631104
# Epoch [24/200]
# Step [10/31], Loss: 0.28488
# Step [20/31], Loss: 0.28272
# Step [30/31], Loss: 0.27704
# Time elasped: 2.4249558448791504
# Epoch [25/200]
# Step [10/31], Loss: 0.27808
# Step [20/31], Loss: 0.27407
# Step [30/31], Loss: 0.27292
# Time elasped: 2.4286458492279053
# avg spk_count per neuron for all 50 timesteps 11.62164306640625
# Test Accuracy of the model on the test samples: 58.447
# Epoch [26/200]
# Step [10/31], Loss: 0.27086
# Step [20/31], Loss: 0.27147
# Step [30/31], Loss: 0.27593
# Time elasped: 2.4322245121002197
# Epoch [27/200]
# Step [10/31], Loss: 0.27051
# Step [20/31], Loss: 0.27289
# Step [30/31], Loss: 0.27924
# Time elasped: 2.4244847297668457
# Epoch [28/200]
# Step [10/31], Loss: 0.26770
# Step [20/31], Loss: 0.27090
# Step [30/31], Loss: 0.27082
# Time elasped: 2.43515682220459
# Epoch [29/200]
# Step [10/31], Loss: 0.26880
# Step [20/31], Loss: 0.26843
# Step [30/31], Loss: 0.26473
# Time elasped: 2.419018268585205
# Epoch [30/200]
# Step [10/31], Loss: 0.26771
# Step [20/31], Loss: 0.26097
# Step [30/31], Loss: 0.25974
# Time elasped: 2.4183058738708496
# avg spk_count per neuron for all 50 timesteps 11.662307739257812
# Test Accuracy of the model on the test samples: 59.521
# Epoch [31/200]
# Step [10/31], Loss: 0.25899
# Step [20/31], Loss: 0.26313
# Step [30/31], Loss: 0.27230
# Time elasped: 2.4500317573547363
# Epoch [32/200]
# Step [10/31], Loss: 0.26610
# Step [20/31], Loss: 0.26645
# Step [30/31], Loss: 0.25830
# Time elasped: 2.4278738498687744
# Epoch [33/200]
# Step [10/31], Loss: 0.25366
# Step [20/31], Loss: 0.25066
# Step [30/31], Loss: 0.25678
# Time elasped: 2.4354002475738525
# Epoch [34/200]
# Step [10/31], Loss: 0.25277
# Step [20/31], Loss: 0.25302
# Step [30/31], Loss: 0.26466
# Time elasped: 2.4187471866607666
# Epoch [35/200]
# Step [10/31], Loss: 0.25427
# Step [20/31], Loss: 0.25186
# Step [30/31], Loss: 0.25370
# Time elasped: 2.4085376262664795
# avg spk_count per neuron for all 50 timesteps 12.175567626953125
# Test Accuracy of the model on the test samples: 57.568
# Epoch [36/200]
# Step [10/31], Loss: 0.25075
# Step [20/31], Loss: 0.24792
# Step [30/31], Loss: 0.24686
# Time elasped: 2.4782605171203613
# Epoch [37/200]
# Step [10/31], Loss: 0.24824
# Step [20/31], Loss: 0.25440
# Step [30/31], Loss: 0.25297
# Time elasped: 2.4265639781951904
# Epoch [38/200]
# Step [10/31], Loss: 0.25626
# Step [20/31], Loss: 0.25119
# Step [30/31], Loss: 0.25140
# Time elasped: 2.4447975158691406
# Epoch [39/200]
# Step [10/31], Loss: 0.24210
# Step [20/31], Loss: 0.24679
# Step [30/31], Loss: 0.24390
# Time elasped: 2.42594575881958
# Epoch [40/200]
# Step [10/31], Loss: 0.24340
# Step [20/31], Loss: 0.24228
# Step [30/31], Loss: 0.24065
# Time elasped: 2.4353365898132324
# avg spk_count per neuron for all 50 timesteps 12.316665649414062
# Test Accuracy of the model on the test samples: 60.742
# Epoch [41/200]
# Step [10/31], Loss: 0.23894
# Step [20/31], Loss: 0.24463
# Step [30/31], Loss: 0.23720
# Time elasped: 2.4629435539245605
# Epoch [42/200]
# Step [10/31], Loss: 0.23688
# Step [20/31], Loss: 0.24207
# Step [30/31], Loss: 0.24272
# Time elasped: 2.454150676727295
# Epoch [43/200]
# Step [10/31], Loss: 0.23643
# Step [20/31], Loss: 0.23844
# Step [30/31], Loss: 0.23388
# Time elasped: 2.435392379760742
# Epoch [44/200]
# Step [10/31], Loss: 0.23303
# Step [20/31], Loss: 0.23698
# Step [30/31], Loss: 0.23658
# Time elasped: 2.4228997230529785
# Epoch [45/200]
# Step [10/31], Loss: 0.23430
# Step [20/31], Loss: 0.23544
# Step [30/31], Loss: 0.23155
# Time elasped: 2.420610189437866
# avg spk_count per neuron for all 50 timesteps 12.527374267578125
# Test Accuracy of the model on the test samples: 56.885
# Epoch [46/200]
# Step [10/31], Loss: 0.23614
# Step [20/31], Loss: 0.23557
# Step [30/31], Loss: 0.23708
# Time elasped: 2.437542200088501
# Epoch [47/200]
# Step [10/31], Loss: 0.22816
# Step [20/31], Loss: 0.23332
# Step [30/31], Loss: 0.22906
# Time elasped: 2.4287121295928955
# Epoch [48/200]
# Step [10/31], Loss: 0.22498
# Step [20/31], Loss: 0.23099
# Step [30/31], Loss: 0.22741
# Time elasped: 2.435993194580078
# Epoch [49/200]
# Step [10/31], Loss: 0.22553
# Step [20/31], Loss: 0.22351
# Step [30/31], Loss: 0.23132
# Time elasped: 2.4336495399475098
# Epoch [50/200]
# Step [10/31], Loss: 0.22661
# Step [20/31], Loss: 0.22672
# Step [30/31], Loss: 0.22821
# Time elasped: 2.4160261154174805
# avg spk_count per neuron for all 50 timesteps 12.682647705078125
# Test Accuracy of the model on the test samples: 58.301
# Epoch [51/200]
# Step [10/31], Loss: 0.22485
# Step [20/31], Loss: 0.22798
# Step [30/31], Loss: 0.22874
# Time elasped: 2.437134265899658
# Epoch [52/200]
# Step [10/31], Loss: 0.22696
# Step [20/31], Loss: 0.22682
# Step [30/31], Loss: 0.23041
# Time elasped: 2.425355911254883
# Epoch [53/200]
# Step [10/31], Loss: 0.22713
# Step [20/31], Loss: 0.22144
# Step [30/31], Loss: 0.22452
# Time elasped: 2.444723129272461
# Epoch [54/200]
# Step [10/31], Loss: 0.21927
# Step [20/31], Loss: 0.22191
# Step [30/31], Loss: 0.21938
# Time elasped: 2.428048610687256
# Epoch [55/200]
# Step [10/31], Loss: 0.21932
# Step [20/31], Loss: 0.23092
# Step [30/31], Loss: 0.23734
# Time elasped: 2.424589157104492
# avg spk_count per neuron for all 50 timesteps 12.44384765625
# Test Accuracy of the model on the test samples: 60.791
# Epoch [56/200]
# Step [10/31], Loss: 0.22697
# Step [20/31], Loss: 0.22122
# Step [30/31], Loss: 0.21583
# Time elasped: 2.444969415664673
# Epoch [57/200]
# Step [10/31], Loss: 0.21320
# Step [20/31], Loss: 0.21691
# Step [30/31], Loss: 0.21845
# Time elasped: 2.4244790077209473
# Epoch [58/200]
# Step [10/31], Loss: 0.21646
# Step [20/31], Loss: 0.21833
# Step [30/31], Loss: 0.21581
# Time elasped: 2.4366650581359863
# Epoch [59/200]
# Step [10/31], Loss: 0.21195
# Step [20/31], Loss: 0.22302
# Step [30/31], Loss: 0.25130
# Time elasped: 2.4173333644866943
# Epoch [60/200]
# Step [10/31], Loss: 0.22873
# Step [20/31], Loss: 0.22556
# Step [30/31], Loss: 0.23259
# Time elasped: 2.4191701412200928
# avg spk_count per neuron for all 50 timesteps 12.477752685546875
# Test Accuracy of the model on the test samples: 62.402
# Epoch [61/200]
# Step [10/31], Loss: 0.24077
# Step [20/31], Loss: 0.22175
# Step [30/31], Loss: 0.21751
# Time elasped: 2.447742462158203
# Epoch [62/200]
# Step [10/31], Loss: 0.21848
# Step [20/31], Loss: 0.21043
# Step [30/31], Loss: 0.21815
# Time elasped: 2.4242217540740967
# Epoch [63/200]
# Step [10/31], Loss: 0.21592
# Step [20/31], Loss: 0.21131
# Step [30/31], Loss: 0.20604
# Time elasped: 2.405538320541382
# Epoch [64/200]
# Step [10/31], Loss: 0.21509
# Step [20/31], Loss: 0.20784
# Step [30/31], Loss: 0.20708
# Time elasped: 2.4258852005004883
# Epoch [65/200]
# Step [10/31], Loss: 0.21490
# Step [20/31], Loss: 0.20948
# Step [30/31], Loss: 0.21210
# Time elasped: 2.4167439937591553
# avg spk_count per neuron for all 50 timesteps 12.45343017578125
# Test Accuracy of the model on the test samples: 61.719
# Epoch [66/200]
# Step [10/31], Loss: 0.20915
# Step [20/31], Loss: 0.20983
# Step [30/31], Loss: 0.21013
# Time elasped: 2.443803071975708
# Epoch [67/200]
# Step [10/31], Loss: 0.20442
# Step [20/31], Loss: 0.20890
# Step [30/31], Loss: 0.20510
# Time elasped: 2.4212074279785156
# Epoch [68/200]
# Step [10/31], Loss: 0.21262
# Step [20/31], Loss: 0.21127
# Step [30/31], Loss: 0.21940
# Time elasped: 2.4163732528686523
# Epoch [69/200]
# Step [10/31], Loss: 0.21344
# Step [20/31], Loss: 0.21144
# Step [30/31], Loss: 0.20392
# Time elasped: 2.4198129177093506
# Epoch [70/200]
# Step [10/31], Loss: 0.20412
# Step [20/31], Loss: 0.20422
# Step [30/31], Loss: 0.20676
# Time elasped: 2.4182183742523193
# avg spk_count per neuron for all 50 timesteps 12.464126586914062
# Test Accuracy of the model on the test samples: 63.477
# Epoch [71/200]
# Step [10/31], Loss: 0.20652
# Step [20/31], Loss: 0.20469
# Step [30/31], Loss: 0.20315
# Time elasped: 2.4490199089050293
# Epoch [72/200]
# Step [10/31], Loss: 0.20613
# Step [20/31], Loss: 0.20338
# Step [30/31], Loss: 0.20129
# Time elasped: 2.412057876586914
# Epoch [73/200]
# Step [10/31], Loss: 0.19787
# Step [20/31], Loss: 0.19863
# Step [30/31], Loss: 0.20608
# Time elasped: 2.418614625930786
# Epoch [74/200]
# Step [10/31], Loss: 0.20186
# Step [20/31], Loss: 0.20281
# Step [30/31], Loss: 0.19796
# Time elasped: 2.4177746772766113
# Epoch [75/200]
# Step [10/31], Loss: 0.20030
# Step [20/31], Loss: 0.20400
# Step [30/31], Loss: 0.20589
# Time elasped: 2.4192371368408203
# avg spk_count per neuron for all 50 timesteps 12.594711303710938
# Test Accuracy of the model on the test samples: 64.111
# Epoch [76/200]
# Step [10/31], Loss: 0.20068
# Step [20/31], Loss: 0.20289
# Step [30/31], Loss: 0.20041
# Time elasped: 2.450031042098999
# Epoch [77/200]
# Step [10/31], Loss: 0.20354
# Step [20/31], Loss: 0.19988
# Step [30/31], Loss: 0.19908
# Time elasped: 2.4124603271484375
# Epoch [78/200]
# Step [10/31], Loss: 0.20321
# Step [20/31], Loss: 0.19798
# Step [30/31], Loss: 0.20333
# Time elasped: 2.4172966480255127
# Epoch [79/200]
# Step [10/31], Loss: 0.20436
# Step [20/31], Loss: 0.20198
# Step [30/31], Loss: 0.20152
# Time elasped: 2.4371535778045654
# Epoch [80/200]
# Step [10/31], Loss: 0.20472
# Step [20/31], Loss: 0.19441
# Step [30/31], Loss: 0.19801
# Time elasped: 2.4163289070129395
# avg spk_count per neuron for all 50 timesteps 12.634124755859375
# Test Accuracy of the model on the test samples: 63.818
# Epoch [81/200]
# Step [10/31], Loss: 0.20077
# Step [20/31], Loss: 0.20250
# Step [30/31], Loss: 0.19636
# Time elasped: 2.4622278213500977
# Epoch [82/200]
# Step [10/31], Loss: 0.20299
# Step [20/31], Loss: 0.20311
# Step [30/31], Loss: 0.19780
# Time elasped: 2.4119210243225098
# Epoch [83/200]
# Step [10/31], Loss: 0.19795
# Step [20/31], Loss: 0.20569
# Step [30/31], Loss: 0.19484
# Time elasped: 2.4269869327545166
# Epoch [84/200]
# Step [10/31], Loss: 0.19705
# Step [20/31], Loss: 0.19595
# Step [30/31], Loss: 0.19492
# Time elasped: 2.41691255569458
# Epoch [85/200]
# Step [10/31], Loss: 0.19041
# Step [20/31], Loss: 0.19773
# Step [30/31], Loss: 0.20244
# Time elasped: 2.4193367958068848
# avg spk_count per neuron for all 50 timesteps 12.559005737304688
# Test Accuracy of the model on the test samples: 64.697
# Epoch [86/200]
# Step [10/31], Loss: 0.19685
# Step [20/31], Loss: 0.19861
# Step [30/31], Loss: 0.19581
# Time elasped: 2.4601447582244873
# Epoch [87/200]
# Step [10/31], Loss: 0.19477
# Step [20/31], Loss: 0.19912
# Step [30/31], Loss: 0.19491
# Time elasped: 2.4116861820220947
# Epoch [88/200]
# Step [10/31], Loss: 0.19699
# Step [20/31], Loss: 0.19573
# Step [30/31], Loss: 0.19591
# Time elasped: 2.477421283721924
# Epoch [89/200]
# Step [10/31], Loss: 0.19061
# Step [20/31], Loss: 0.19684
# Step [30/31], Loss: 0.19496
# Time elasped: 2.442620277404785
# Epoch [90/200]
# Step [10/31], Loss: 0.19448
# Step [20/31], Loss: 0.19319
# Step [30/31], Loss: 0.19077
# Time elasped: 2.427508592605591
# avg spk_count per neuron for all 50 timesteps 12.6728515625
# Test Accuracy of the model on the test samples: 64.160
# Epoch [91/200]
# Step [10/31], Loss: 0.19378
# Step [20/31], Loss: 0.19115
# Step [30/31], Loss: 0.19394
# Time elasped: 2.5447587966918945
# Epoch [92/200]
# Step [10/31], Loss: 0.19396
# Step [20/31], Loss: 0.19080
# Step [30/31], Loss: 0.19191
# Time elasped: 2.419747829437256
# Epoch [93/200]
# Step [10/31], Loss: 0.19099
# Step [20/31], Loss: 0.19379
# Step [30/31], Loss: 0.19417
# Time elasped: 2.4092702865600586
# Epoch [94/200]
# Step [10/31], Loss: 0.19120
# Step [20/31], Loss: 0.19218
# Step [30/31], Loss: 0.19198
# Time elasped: 2.4265997409820557
# Epoch [95/200]
# Step [10/31], Loss: 0.19579
# Step [20/31], Loss: 0.19501
# Step [30/31], Loss: 0.19045
# Time elasped: 2.4139668941497803
# avg spk_count per neuron for all 50 timesteps 12.739654541015625
# Test Accuracy of the model on the test samples: 62.500
# Epoch [96/200]
# Step [10/31], Loss: 0.19135
# Step [20/31], Loss: 0.19480
# Step [30/31], Loss: 0.19107
# Time elasped: 2.4353175163269043
# Epoch [97/200]
# Step [10/31], Loss: 0.18569
# Step [20/31], Loss: 0.19333
# Step [30/31], Loss: 0.19403
# Time elasped: 2.4174156188964844
# Epoch [98/200]
# Step [10/31], Loss: 0.19106
# Step [20/31], Loss: 0.19373
# Step [30/31], Loss: 0.19082
# Time elasped: 2.4103424549102783
# Epoch [99/200]
# Step [10/31], Loss: 0.19188
# Step [20/31], Loss: 0.19496
# Step [30/31], Loss: 0.18834
# Time elasped: 2.4185614585876465
# Epoch [100/200]
# Step [10/31], Loss: 0.19082
# Step [20/31], Loss: 0.19437
# Step [30/31], Loss: 0.18854
# Time elasped: 2.4185357093811035
# avg spk_count per neuron for all 50 timesteps 12.680023193359375
# Test Accuracy of the model on the test samples: 63.916
# Epoch [101/200]
# Step [10/31], Loss: 0.19281
# Step [20/31], Loss: 0.18891
# Step [30/31], Loss: 0.19759
# Time elasped: 2.446136713027954
# Epoch [102/200]
# Step [10/31], Loss: 0.18943
# Step [20/31], Loss: 0.19227
# Step [30/31], Loss: 0.18815
# Time elasped: 2.425403356552124
# Epoch [103/200]
# Step [10/31], Loss: 0.18933
# Step [20/31], Loss: 0.19379
# Step [30/31], Loss: 0.18601
# Time elasped: 2.4207568168640137
# Epoch [104/200]
# Step [10/31], Loss: 0.18796
# Step [20/31], Loss: 0.18472
# Step [30/31], Loss: 0.19094
# Time elasped: 2.425165891647339
# Epoch [105/200]
# Step [10/31], Loss: 0.18826
# Step [20/31], Loss: 0.18825
# Step [30/31], Loss: 0.19011
# Time elasped: 2.457667589187622
# avg spk_count per neuron for all 50 timesteps 12.677902221679688
# Test Accuracy of the model on the test samples: 63.916
# Epoch [106/200]
# Step [10/31], Loss: 0.18562
# Step [20/31], Loss: 0.19013
# Step [30/31], Loss: 0.18184
# Time elasped: 2.4449188709259033
# Epoch [107/200]
# Step [10/31], Loss: 0.18820
# Step [20/31], Loss: 0.18537
# Step [30/31], Loss: 0.18603
# Time elasped: 2.4260635375976562
# Epoch [108/200]
# Step [10/31], Loss: 0.18693
# Step [20/31], Loss: 0.18788
# Step [30/31], Loss: 0.19033
# Time elasped: 2.4203813076019287
# Epoch [109/200]
# Step [10/31], Loss: 0.18984
# Step [20/31], Loss: 0.18282
# Step [30/31], Loss: 0.18731
# Time elasped: 2.4267537593841553
# Epoch [110/200]
# Step [10/31], Loss: 0.18261
# Step [20/31], Loss: 0.18490
# Step [30/31], Loss: 0.18772
# Time elasped: 2.432659864425659
# avg spk_count per neuron for all 50 timesteps 12.795700073242188
# Test Accuracy of the model on the test samples: 63.672
# Epoch [111/200]
# Step [10/31], Loss: 0.19055
# Step [20/31], Loss: 0.18500
# Step [30/31], Loss: 0.18633
# Time elasped: 2.4700684547424316
# Epoch [112/200]
# Step [10/31], Loss: 0.18404
# Step [20/31], Loss: 0.19250
# Step [30/31], Loss: 0.18601
# Time elasped: 2.420037269592285
# Epoch [113/200]
# Step [10/31], Loss: 0.18555
# Step [20/31], Loss: 0.18681
# Step [30/31], Loss: 0.18407
# Time elasped: 2.4404544830322266
# Epoch [114/200]
# Step [10/31], Loss: 0.18364
# Step [20/31], Loss: 0.18340
# Step [30/31], Loss: 0.18381
# Time elasped: 2.404587745666504
# Epoch [115/200]
# Step [10/31], Loss: 0.18682
# Step [20/31], Loss: 0.18823
# Step [30/31], Loss: 0.18395
# Time elasped: 2.410684108734131
# avg spk_count per neuron for all 50 timesteps 12.768600463867188
# Test Accuracy of the model on the test samples: 63.818
# Epoch [116/200]
# Step [10/31], Loss: 0.18619
# Step [20/31], Loss: 0.18439
# Step [30/31], Loss: 0.18969
# Time elasped: 2.433932304382324
# Epoch [117/200]
# Step [10/31], Loss: 0.18271
# Step [20/31], Loss: 0.18415
# Step [30/31], Loss: 0.18954
# Time elasped: 2.4180002212524414
# Epoch [118/200]
# Step [10/31], Loss: 0.18353
# Step [20/31], Loss: 0.18609
# Step [30/31], Loss: 0.18636
# Time elasped: 2.4715960025787354
# Epoch [119/200]
# Step [10/31], Loss: 0.18315
# Step [20/31], Loss: 0.18089
# Step [30/31], Loss: 0.18652
# Time elasped: 2.448444128036499
# Epoch [120/200]
# Step [10/31], Loss: 0.18411
# Step [20/31], Loss: 0.18638
# Step [30/31], Loss: 0.18197
# Time elasped: 2.4188129901885986
# avg spk_count per neuron for all 50 timesteps 12.792022705078125
# Test Accuracy of the model on the test samples: 63.916
# Epoch [121/200]
# Step [10/31], Loss: 0.18226
# Step [20/31], Loss: 0.18612
# Step [30/31], Loss: 0.18688
# Time elasped: 2.44671368598938
# Epoch [122/200]
# Step [10/31], Loss: 0.17835
# Step [20/31], Loss: 0.18699
# Step [30/31], Loss: 0.18941
# Time elasped: 2.417785406112671
# Epoch [123/200]
# Step [10/31], Loss: 0.18588
# Step [20/31], Loss: 0.18343
# Step [30/31], Loss: 0.18198
# Time elasped: 2.451054811477661
# Epoch [124/200]
# Step [10/31], Loss: 0.18554
# Step [20/31], Loss: 0.18384
# Step [30/31], Loss: 0.18100
# Time elasped: 2.419572353363037
# Epoch [125/200]
# Step [10/31], Loss: 0.18214
# Step [20/31], Loss: 0.17773
# Step [30/31], Loss: 0.18513
# Time elasped: 2.417280435562134
# avg spk_count per neuron for all 50 timesteps 12.8836669921875
# Test Accuracy of the model on the test samples: 63.184
# Epoch [126/200]
# Step [10/31], Loss: 0.18423
# Step [20/31], Loss: 0.18258
# Step [30/31], Loss: 0.18573
# Time elasped: 2.4351136684417725
# Epoch [127/200]
# Step [10/31], Loss: 0.18172
# Step [20/31], Loss: 0.18331
# Step [30/31], Loss: 0.18438
# Time elasped: 2.4301540851593018
# Epoch [128/200]
# Step [10/31], Loss: 0.18287
# Step [20/31], Loss: 0.17868
# Step [30/31], Loss: 0.18212
# Time elasped: 2.425713539123535
# Epoch [129/200]
# Step [10/31], Loss: 0.18204
# Step [20/31], Loss: 0.18437
# Step [30/31], Loss: 0.18378
# Time elasped: 2.410158395767212
# Epoch [130/200]
# Step [10/31], Loss: 0.17576
# Step [20/31], Loss: 0.18569
# Step [30/31], Loss: 0.18401
# Time elasped: 2.4302268028259277
# avg spk_count per neuron for all 50 timesteps 12.710159301757812
# Test Accuracy of the model on the test samples: 63.379
# Epoch [131/200]
# Step [10/31], Loss: 0.18296
# Step [20/31], Loss: 0.18522
# Step [30/31], Loss: 0.17949
# Time elasped: 2.5506834983825684
# Epoch [132/200]
# Step [10/31], Loss: 0.17821
# Step [20/31], Loss: 0.18549
# Step [30/31], Loss: 0.18070
# Time elasped: 2.5590054988861084
# Epoch [133/200]
# Step [10/31], Loss: 0.17941
# Step [20/31], Loss: 0.18248
# Step [30/31], Loss: 0.18233
# Time elasped: 2.5898661613464355
# Epoch [134/200]
# Step [10/31], Loss: 0.17723
# Step [20/31], Loss: 0.18403
# Step [30/31], Loss: 0.18410
# Time elasped: 2.613037586212158
# Epoch [135/200]
# Step [10/31], Loss: 0.17861
# Step [20/31], Loss: 0.18381
# Step [30/31], Loss: 0.18285
# Time elasped: 2.5355820655822754
# avg spk_count per neuron for all 50 timesteps 12.6661376953125
# Test Accuracy of the model on the test samples: 64.551
# Epoch [136/200]
# Step [10/31], Loss: 0.17959
# Step [20/31], Loss: 0.18303
# Step [30/31], Loss: 0.17918
# Time elasped: 2.4569146633148193
# Epoch [137/200]
# Step [10/31], Loss: 0.18076
# Step [20/31], Loss: 0.18229
# Step [30/31], Loss: 0.17821
# Time elasped: 2.499549388885498
# Epoch [138/200]
# Step [10/31], Loss: 0.17692
# Step [20/31], Loss: 0.18166
# Step [30/31], Loss: 0.18757
# Time elasped: 2.408655881881714
# Epoch [139/200]
# Step [10/31], Loss: 0.18072
# Step [20/31], Loss: 0.18241
# Step [30/31], Loss: 0.18082
# Time elasped: 2.4175596237182617
# Epoch [140/200]
# Step [10/31], Loss: 0.18087
# Step [20/31], Loss: 0.17934
# Step [30/31], Loss: 0.18172
# Time elasped: 2.445622205734253
# avg spk_count per neuron for all 50 timesteps 12.784103393554688
# Test Accuracy of the model on the test samples: 64.746
# Epoch [141/200]
# Step [10/31], Loss: 0.17807
# Step [20/31], Loss: 0.18333
# Step [30/31], Loss: 0.18190
# Time elasped: 2.420032024383545
# Epoch [142/200]
# Step [10/31], Loss: 0.17674
# Step [20/31], Loss: 0.18340
# Step [30/31], Loss: 0.18057
# Time elasped: 2.4093217849731445
# Epoch [143/200]
# Step [10/31], Loss: 0.17839
# Step [20/31], Loss: 0.17707
# Step [30/31], Loss: 0.18029
# Time elasped: 2.418264627456665
# Epoch [144/200]
# Step [10/31], Loss: 0.18152
# Step [20/31], Loss: 0.17810
# Step [30/31], Loss: 0.17990
# Time elasped: 2.4183592796325684
# Epoch [145/200]
# Step [10/31], Loss: 0.17727
# Step [20/31], Loss: 0.18411
# Step [30/31], Loss: 0.17822
# Time elasped: 2.419264078140259
# avg spk_count per neuron for all 50 timesteps 12.77740478515625
# Test Accuracy of the model on the test samples: 64.111
# Epoch [146/200]
# Step [10/31], Loss: 0.17406
# Step [20/31], Loss: 0.18195
# Step [30/31], Loss: 0.18227
# Time elasped: 2.445098400115967
# Epoch [147/200]
# Step [10/31], Loss: 0.18224
# Step [20/31], Loss: 0.17752
# Step [30/31], Loss: 0.17634
# Time elasped: 2.4174838066101074
# Epoch [148/200]
# Step [10/31], Loss: 0.17955
# Step [20/31], Loss: 0.17486
# Step [30/31], Loss: 0.18105
# Time elasped: 2.40382719039917
# Epoch [149/200]
# Step [10/31], Loss: 0.17928
# Step [20/31], Loss: 0.18162
# Step [30/31], Loss: 0.17161
# Time elasped: 2.4166998863220215
# Epoch [150/200]
# Step [10/31], Loss: 0.18293
# Step [20/31], Loss: 0.17322
# Step [30/31], Loss: 0.17772
# Time elasped: 2.4281821250915527
# avg spk_count per neuron for all 50 timesteps 12.822769165039062
# Test Accuracy of the model on the test samples: 64.551
# Epoch [151/200]
# Step [10/31], Loss: 0.18023
# Step [20/31], Loss: 0.18208
# Step [30/31], Loss: 0.17618
# Time elasped: 2.42781138420105
# Epoch [152/200]
# Step [10/31], Loss: 0.17964
# Step [20/31], Loss: 0.17682
# Step [30/31], Loss: 0.18063
# Time elasped: 2.4174416065216064
# Epoch [153/200]
# Step [10/31], Loss: 0.17752
# Step [20/31], Loss: 0.17928
# Step [30/31], Loss: 0.17889
# Time elasped: 2.4255716800689697
# Epoch [154/200]
# Step [10/31], Loss: 0.17984
# Step [20/31], Loss: 0.17595
# Step [30/31], Loss: 0.18258
# Time elasped: 2.422236204147339
# Epoch [155/200]
# Step [10/31], Loss: 0.17525
# Step [20/31], Loss: 0.17920
# Step [30/31], Loss: 0.17473
# Time elasped: 2.4091553688049316
# avg spk_count per neuron for all 50 timesteps 12.991531372070312
# Test Accuracy of the model on the test samples: 64.160
# Epoch [156/200]
# Step [10/31], Loss: 0.17849
# Step [20/31], Loss: 0.18075
# Step [30/31], Loss: 0.17352
# Time elasped: 2.4261698722839355
# Epoch [157/200]
# Step [10/31], Loss: 0.18291
# Step [20/31], Loss: 0.17707
# Step [30/31], Loss: 0.17549
# Time elasped: 2.4607386589050293
# Epoch [158/200]
# Step [10/31], Loss: 0.17730
# Step [20/31], Loss: 0.17729
# Step [30/31], Loss: 0.18133
# Time elasped: 2.4193413257598877
# Epoch [159/200]
# Step [10/31], Loss: 0.17852
# Step [20/31], Loss: 0.17557
# Step [30/31], Loss: 0.17492
# Time elasped: 2.415867328643799
# Epoch [160/200]
# Step [10/31], Loss: 0.17366
# Step [20/31], Loss: 0.17840
# Step [30/31], Loss: 0.17584
# Time elasped: 2.4296109676361084
# avg spk_count per neuron for all 50 timesteps 12.748809814453125
# Test Accuracy of the model on the test samples: 65.771
# Epoch [161/200]
# Step [10/31], Loss: 0.17930
# Step [20/31], Loss: 0.18173
# Step [30/31], Loss: 0.16975
# Time elasped: 2.4361412525177
# Epoch [162/200]
# Step [10/31], Loss: 0.18033
# Step [20/31], Loss: 0.17039
# Step [30/31], Loss: 0.17939
# Time elasped: 2.413114547729492
# Epoch [163/200]
# Step [10/31], Loss: 0.17790
# Step [20/31], Loss: 0.17951
# Step [30/31], Loss: 0.17652
# Time elasped: 2.418565034866333
# Epoch [164/200]
# Step [10/31], Loss: 0.17701
# Step [20/31], Loss: 0.17580
# Step [30/31], Loss: 0.17614
# Time elasped: 2.416973352432251
# Epoch [165/200]
# Step [10/31], Loss: 0.17856
# Step [20/31], Loss: 0.17726
# Step [30/31], Loss: 0.17672
# Time elasped: 2.4251596927642822
# avg spk_count per neuron for all 50 timesteps 12.76287841796875
# Test Accuracy of the model on the test samples: 64.648
# Epoch [166/200]
# Step [10/31], Loss: 0.18024
# Step [20/31], Loss: 0.17865
# Step [30/31], Loss: 0.17801
# Time elasped: 2.4503209590911865
# Epoch [167/200]
# Step [10/31], Loss: 0.17836
# Step [20/31], Loss: 0.17579
# Step [30/31], Loss: 0.18061
# Time elasped: 2.4116504192352295
# Epoch [168/200]
# Step [10/31], Loss: 0.17766
# Step [20/31], Loss: 0.17417
# Step [30/31], Loss: 0.17908
# Time elasped: 2.4196715354919434
# Epoch [169/200]
# Step [10/31], Loss: 0.17781
# Step [20/31], Loss: 0.17857
# Step [30/31], Loss: 0.17511
# Time elasped: 2.41753888130188
# Epoch [170/200]
# Step [10/31], Loss: 0.18160
# Step [20/31], Loss: 0.17658
# Step [30/31], Loss: 0.17689
# Time elasped: 2.426288604736328
# avg spk_count per neuron for all 50 timesteps 12.789321899414062
# Test Accuracy of the model on the test samples: 65.723
# Epoch [171/200]
# Step [10/31], Loss: 0.17526
# Step [20/31], Loss: 0.17888
# Step [30/31], Loss: 0.17844
# Time elasped: 2.4290671348571777
# Epoch [172/200]
# Step [10/31], Loss: 0.17394
# Step [20/31], Loss: 0.18050
# Step [30/31], Loss: 0.17471
# Time elasped: 2.418992519378662
# Epoch [173/200]
# Step [10/31], Loss: 0.17767
# Step [20/31], Loss: 0.17402
# Step [30/31], Loss: 0.17662
# Time elasped: 2.424947738647461
# Epoch [174/200]
# Step [10/31], Loss: 0.17616
# Step [20/31], Loss: 0.17688
# Step [30/31], Loss: 0.17301
# Time elasped: 2.4283528327941895
# Epoch [175/200]
# Step [10/31], Loss: 0.17717
# Step [20/31], Loss: 0.17460
# Step [30/31], Loss: 0.18293
# Time elasped: 2.4511375427246094
# avg spk_count per neuron for all 50 timesteps 12.627151489257812
# Test Accuracy of the model on the test samples: 64.307
# Epoch [176/200]
# Step [10/31], Loss: 0.17858
# Step [20/31], Loss: 0.17519
# Step [30/31], Loss: 0.17321
# Time elasped: 2.436366558074951
# Epoch [177/200]
# Step [10/31], Loss: 0.17415
# Step [20/31], Loss: 0.17736
# Step [30/31], Loss: 0.17789
# Time elasped: 2.427386999130249
# Epoch [178/200]
# Step [10/31], Loss: 0.17882
# Step [20/31], Loss: 0.17234
# Step [30/31], Loss: 0.17719
# Time elasped: 2.419053792953491
# Epoch [179/200]
# Step [10/31], Loss: 0.17690
# Step [20/31], Loss: 0.17444
# Step [30/31], Loss: 0.17553
# Time elasped: 2.420048236846924
# Epoch [180/200]
# Step [10/31], Loss: 0.17786
# Step [20/31], Loss: 0.17452
# Step [30/31], Loss: 0.17821
# Time elasped: 2.4243335723876953
# avg spk_count per neuron for all 50 timesteps 12.791854858398438
# Test Accuracy of the model on the test samples: 65.820
# Epoch [181/200]
# Step [10/31], Loss: 0.17799
# Step [20/31], Loss: 0.17538
# Step [30/31], Loss: 0.17509
# Time elasped: 2.433295249938965
# Epoch [182/200]
# Step [10/31], Loss: 0.17930
# Step [20/31], Loss: 0.17910
# Step [30/31], Loss: 0.17310
# Time elasped: 2.460355758666992
# Epoch [183/200]
# Step [10/31], Loss: 0.17605
# Step [20/31], Loss: 0.17394
# Step [30/31], Loss: 0.17391
# Time elasped: 2.4437575340270996
# Epoch [184/200]
# Step [10/31], Loss: 0.17796
# Step [20/31], Loss: 0.17599
# Step [30/31], Loss: 0.17765
# Time elasped: 2.418423891067505
# Epoch [185/200]
# Step [10/31], Loss: 0.17487
# Step [20/31], Loss: 0.17709
# Step [30/31], Loss: 0.17471
# Time elasped: 2.4118990898132324
# avg spk_count per neuron for all 50 timesteps 12.84417724609375
# Test Accuracy of the model on the test samples: 65.186
# Epoch [186/200]
# Step [10/31], Loss: 0.17947
# Step [20/31], Loss: 0.17765
# Step [30/31], Loss: 0.17048
# Time elasped: 2.4320743083953857
# Epoch [187/200]
# Step [10/31], Loss: 0.17491
# Step [20/31], Loss: 0.17761
# Step [30/31], Loss: 0.17895
# Time elasped: 2.4161436557769775
# Epoch [188/200]
# Step [10/31], Loss: 0.17282
# Step [20/31], Loss: 0.17807
# Step [30/31], Loss: 0.17462
# Time elasped: 2.428557872772217
# Epoch [189/200]
# Step [10/31], Loss: 0.17722
# Step [20/31], Loss: 0.17465
# Step [30/31], Loss: 0.17567
# Time elasped: 2.429893970489502
# Epoch [190/200]
# Step [10/31], Loss: 0.17889
# Step [20/31], Loss: 0.17254
# Step [30/31], Loss: 0.17294
# Time elasped: 2.413831949234009
# avg spk_count per neuron for all 50 timesteps 12.80181884765625
# Test Accuracy of the model on the test samples: 65.625
# Epoch [191/200]
# Step [10/31], Loss: 0.17593
# Step [20/31], Loss: 0.17635
# Step [30/31], Loss: 0.17332
# Time elasped: 2.442460775375366
# Epoch [192/200]
# Step [10/31], Loss: 0.17457
# Step [20/31], Loss: 0.17462
# Step [30/31], Loss: 0.17634
# Time elasped: 2.469283103942871
# Epoch [193/200]
# Step [10/31], Loss: 0.17628
# Step [20/31], Loss: 0.17902
# Step [30/31], Loss: 0.17117
# Time elasped: 2.4183082580566406
# Epoch [194/200]
# Step [10/31], Loss: 0.17763
# Step [20/31], Loss: 0.17518
# Step [30/31], Loss: 0.17510
# Time elasped: 2.427642583847046
# Epoch [195/200]
# Step [10/31], Loss: 0.17699
# Step [20/31], Loss: 0.17651
# Step [30/31], Loss: 0.17186
# Time elasped: 2.417201519012451
# avg spk_count per neuron for all 50 timesteps 12.63311767578125
# Test Accuracy of the model on the test samples: 65.723
# Epoch [196/200]
# Step [10/31], Loss: 0.17398
# Step [20/31], Loss: 0.17517
# Step [30/31], Loss: 0.17196
# Time elasped: 2.451977014541626
# Epoch [197/200]
# Step [10/31], Loss: 0.17478
# Step [20/31], Loss: 0.17179
# Step [30/31], Loss: 0.17841
# Time elasped: 2.418257474899292
# Epoch [198/200]
# Step [10/31], Loss: 0.17101
# Step [20/31], Loss: 0.17522
# Step [30/31], Loss: 0.17980
# Time elasped: 2.42616868019104
# Epoch [199/200]
# Step [10/31], Loss: 0.17874
# Step [20/31], Loss: 0.17595
# Step [30/31], Loss: 0.17172
# Time elasped: 2.4280881881713867
# Epoch [200/200]
# Step [10/31], Loss: 0.17368
# Step [20/31], Loss: 0.17877
# Step [30/31], Loss: 0.17235
# Time elasped: 2.537438154220581
# avg spk_count per neuron for all 50 timesteps 12.741531372070312
# Test Accuracy of the model on the test samples: 64.844

# %%
# Out:
# Step [10/31], Loss: 0.57292
# Step [20/31], Loss: 0.57104
# Step [30/31], Loss: 0.57833
# avg spk_count per neuron for all 50 timesteps 6.2415924072265625
# Test Accuracy of the model on the test samples: 3.320
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-22-fbe3982bef36> in <module>
#       3 snn.train_step(train_loader, optimizer=optimizer, criterion=nn.MSELoss(), num_samples = num_samples, spkreg=0.01)
#       4 snn.test(test_loader, criterion=nn.MSELoss())
# ----> 5 snn.save_to_numpy(modelname[:-3])
#
# ~\SRNNs\notebooks\snn_models.py in save_to_numpy(self, directory)
#     228             spk = self.test_spk_count[-1][1].detach().cpu().numpy()
#     229             print(spk)
# --> 230             logs.write("avg spk neuron/sample {}".format(spk))
#     231             logs.write("avg spk neuron/timestep {}".format(spk*(self.num_hidden/self.win)))
#     232
#
# TypeError: can't multiply sequence by non-int of type 'float'

# %%
snn.test_spk_count[-1][1].detach().cpu().numpy()
# Out:
# array(12.741531, dtype=float32)

# %%
modelname[:-3]

# %%
snn.test(test_loader, criterion=nn.MSELoss())
fig = snn.plot_activity('h','spike','normal', [0,1,2,3,4])

# %%
fig = snn.plot_activity('x','spike','normal', range(1))

# %%
# neuron_id -> id of neurons to display
# sample_id -> id of sample to display
fig = snn.plot_mem('h', neuron_id =[0, 1, 2], sample_id = [0,1])

# %%
def square(num):
    '''
    get two closest factors of num so we can plot a vector of length num as an square-ish matrix
    '''
    factor1 = [x for x in range(1,num+1) if num%x==0 ]
    factor2 = [int(num/x) for x in factor1]
    idx = np.argmin(np.abs(np.array(factor2) - np.array(factor1)))
    return factor1[idx], factor2[idx]

# %%
# %matplotlib notebook
from matplotlib.animation import FuncAnimation

xh, yh = square(snn.num_hidden)

hidden_spk = snn.all_h_spike.permute(1,0,2).flatten(0,1).view(-1, xh, yh).detach().cpu().numpy()

output_spk = snn.all_o_spike.view(-1,snn.num_output).detach().cpu().numpy()

num_channels = 2

ni = int(snn.num_input / num_channels)
xx, yx = square(ni)

hidden_spk[0,0,0] = 1.0

fig = plt.figure()

gs = fig.add_gridspec(2,2)

if num_channels==1:
    ax1 = fig.add_subplot(gs[:, 0])
    x_spk = snn.all_x.permute(1,0,2).flatten(0,1).view(-1, xx, yx).detach().cpu().numpy()
    x_spk[0,0,0] = 1.0
    im_x = ax1.imshow(x_spk[0,:,:])
elif num_channels ==2:
    ax1 = fig.add_subplot(gs[0, 0])
    ax2 = fig.add_subplot(gs[1, 0])
    
    x_spk_1 = snn.all_x.permute(1,0,2).flatten(0,1)[:,:ni].view(-1, xx, yx).detach().cpu().numpy()
    x_spk_2 = snn.all_x.permute(1,0,2).flatten(0,1)[:,ni:].view(-1, xx, yx).detach().cpu().numpy()

    x_spk_1[0,0,0] = 1.0 
    x_spk_2[0,0,0] = 1.0
    im_x_1 = ax1.imshow(x_spk_1[0,:,:])
    im_x_2 = ax2.imshow(x_spk_2[0,:,:])
    
ax3 = fig.add_subplot(gs[0, 1])
ax4 = fig.add_subplot(gs[1, 1])
#ax4 = fig.add_subplot(gs[0, 2])
#ax5 = fig.add_subplot(gs[1, 2])

im_h = ax3.imshow(hidden_spk[0,:,:])
ax4.set_xlim(0,1000)
ax4.set_ylim(0,int(snn.num_hidden/3))
spk, = ax4.plot([])
avg_spk, = ax4.plot([])

t = np.arange(1000)
spk_data = np.zeros(1000)
avg_spk_data = np.zeros(1000)



def animate(frame_num):
    
    spk_data[frame_num] = hidden_spk[frame_num,:,:].sum()
    avg_spk_data[frame_num] = spk_data[:frame_num].mean()
    
    if num_channels==1:
        im_x.set_data(x_spk[frame_num,:,:])
    else:
        im_x_1.set_data(x_spk_1[frame_num,:,:])
        im_x_2.set_data(x_spk_2[frame_num,:,:])
    im_h.set_data(hidden_spk[frame_num,:,:])
    spk.set_data((t, spk_data))
    avg_spk.set_data((t, avg_spk_data))
    #im_h1.set_data(hidden_spk[t,:,:])    
    #return (im_x, im_h)

anim = FuncAnimation(fig, animate, frames=1000, interval=10)
plt.show()

# %%
#tau_m = 'adp'
tau_m = 0.8305
#snn = RSNN_delay(d='shd', num_hidden=128, thresh=0.3, decay=0.3, batch_size=batch_size, win=50, device=device)
snn_r = RSNN_monitor('shd', num_hidden=256, thresh=0.3, tau_m=tau_m, batch_size=batch_size, win=time_window, device=device)
snn_r.to(device)

# training configuration

num_epochs = 200
modelname = 'shd_rnn_{}r.t7'.format(snn_r.num_hidden, tau_m)
num_samples = train_dataset.images.size()[0]

#optimizer = torch.optim.Adam(snn.parameters(), lr=learning_rate)

# set different learning rates
base_params = [snn_r.fc_ih.weight,
               snn_r.fc_hh.weight,
               snn_r.fc_ho.weight, 
               ]
if tau_m=='adp':
    print('tau_m_h ')
    optimizer = torch.optim.Adam([
        {'params': base_params},
        {'params': snn_r.tau_m_h, 'lr': learning_rate * 10.0}],
        lr=learning_rate)
else:    
    optimizer = torch.optim.Adam([
        {'params': base_params}],
        lr=learning_rate)
    
act_fun = ActFun.apply
print(modelname)

for epoch in range(num_epochs):
    print('Epoch [%d/%d]'  % (epoch + 1, num_epochs))
    start_time = time.time()
    snn_r.train_step(train_loader, optimizer=optimizer, criterion=nn.MSELoss(), num_samples = num_samples, spkreg=0.1)
    print('Time elasped:', time.time() - start_time)
    
    # update learning rate
    optimizer = snn_r.lr_scheduler(optimizer, lr_decay_epoch=1)
    
    if (epoch + 1) % 5 == 0:
        snn_r.test(test_loader, criterion=nn.MSELoss())
        #snn.save_model(modelname)

# %%
# %matplotlib notebook
from matplotlib.animation import FuncAnimation
from matplotlib.animation import PillowWriter

xh, yh = square(snn.num_hidden)
xx, yx = square(snn.num_input)

hidden_spk = snn.all_h_spike.permute(1,0,2).flatten(0,1).view(-1, xh, yh).detach().cpu().numpy()
hidden_spk_r = snn_r.all_h_spike.permute(1,0,2).flatten(0,1).view(-1, xh, yh).detach().cpu().numpy()

x_spk = snn.all_x.permute(1,0,2).flatten(0,1).view(-1, xx, yx).detach().cpu().numpy()
#output_spk = snn.all_o_spike.view(-1,snn.num_output).detach().cpu().numpy()

print(hidden_spk.sum())
print(hidden_spk_r.sum())

fig = plt.figure()

gs = fig.add_gridspec(2,3)

ax1 = fig.add_subplot(gs[:, 0])
x_spk = snn.all_x.permute(1,0,2).flatten(0,1).view(-1, xx, yx).detach().cpu().numpy()
x_spk[0,0,0] = 1.0
im_x = ax1.imshow(x_spk[0,:,:])
    
    
ax3 = fig.add_subplot(gs[0, 1])
ax4 = fig.add_subplot(gs[1, 1])
ax5 = fig.add_subplot(gs[0, 2])
ax6 = fig.add_subplot(gs[1, 2])

im_h = ax3.imshow(hidden_spk[0,:,:])
ax4.set_xlim(0,1000)
ax4.set_ylim(0,int(snn.num_hidden/3))
spk, = ax4.plot([])
avg_spk, = ax4.plot([])

t = np.arange(1000)
spk_data = np.zeros(1000)
avg_spk_data = np.zeros(1000)

hidden_spk[0,0,0] = 1.0
hidden_spk_r[0,0,0] = 1.0


im_x = ax1.imshow(x_spk[0,:,:])
im_h = ax3.imshow(hidden_spk[0,:,:])     # A tuple unpacking to unpack the only plot

im_h_r = ax5.imshow(hidden_spk_r[0,:,:])     # A tuple unpacking to unpack the only plot

ax4.set_xlim(0,1000)
ax4.set_ylim(0,int(snn.num_hidden/2))

ax6.set_xlim(0,1000)
ax6.set_ylim(0,int(snn.num_hidden/2))

spk, = ax4.plot([])
avg_spk, = ax4.plot([])

spk_r, = ax6.plot([])
avg_spk_r, = ax6.plot([])

t = np.arange(1000)
spk_data = np.zeros(1000)
avg_spk_data = np.zeros(1000)
spk_data_r = np.zeros(1000)
avg_spk_data_r = np.zeros(1000)

#ax.set_xlim(0, 2*np.pi)
#ax.set_ylim(-1.1, 1.1)

def animate(frame_num):
    
    spk_data[frame_num] = hidden_spk[frame_num,:,:].sum()
    avg_spk_data[frame_num] = spk_data[:frame_num].mean()

    spk_data_r[frame_num] = hidden_spk_r[frame_num,:,:].sum()
    avg_spk_data_r[frame_num] = spk_data_r[:frame_num].mean()    
    
    im_x.set_data(x_spk[frame_num,:,:])
    im_h.set_data(hidden_spk[frame_num,:,:])
    im_h_r.set_data(hidden_spk_r[frame_num,:,:])
    spk.set_data((t, spk_data))
    avg_spk.set_data((t, avg_spk_data))
    spk_r.set_data((t, spk_data_r))
    avg_spk_r.set_data((t, avg_spk_data_r))    
    
    #im_h1.set_data(hidden_spk[t,:,:])    
    return (im_x, im_h)



anim = FuncAnimation(fig, animate, frames=1000, interval=10)
#anim.save('reg_effect.gif', writer = PillowWriter(fps=15))
plt.show()

# %%
Dictionary1 = {'A': 'Geeks', 'B': 'For'}

# %%
'A' in Dictionary1.keys()

# %%
ax[0,0]

# %%
plt.imshow(hidden_spk[25,:,:])

# %%
snn.all_h_spike

# %%
hidden_spk[25,:]

# %%
hidden_spk.

# %%
snn.all_h_spike[25,0,:]

# %%
snn.all_h_spike[25,0,:].shape

# %%
snn.all_h_spike.shape

# %% [markdown]
# #### Single neuron analysis

# %%
from MyDataset import *

time_window = 50
batch_size = 1
#device = 'cuda:0'
device = device

dataset_path = r'./../../datasets'
test_path = dataset_path+'/shd_digits/shd_test.h5'

#test_dataset = MyDataset(test_path, 'hd_digits', time_window, device)

test_dataset = MyDataset(path ='1_20', method= 'random', win=time_window, device=device,num_samples = None)
test_dataset.images = torch.zeros(test_dataset.images.shape)

#test_dataset.images[0, 10, 5] = 1.0
#test_dataset.images[0, 11, 5] = 1.0
test_dataset.images[0, 12, 5] = 1.0
test_dataset.images[0, 12, 6] = 1.0
test_dataset.images[0, 2, 5] = 1.0
test_dataset.images[0, 20, 5] = 1.0

# %%
test_loader = torch.utils.data.DataLoader(dataset=test_dataset,
                                          batch_size=batch_size,
                                          shuffle=False, drop_last=False)

# %%
#tau_m = 'adp'
tau_m = 0.8305
#snn = RSNN_delay(d='shd', num_hidden=128, thresh=0.3, decay=0.3, batch_size=batch_size, win=50, device=device)
snn2 = RSNN_monitor('custom_20_10', num_hidden=10, thresh=0.3, tau_m=tau_m, batch_size=batch_size, win=time_window, device=device)
snn2.to(device)

# %%
snn2.fc_ih.weight = torch.nn.Parameter(0.2*torch.ones(snn2.fc_ih.weight.shape, device=device))
snn2.fc_hh.weight = torch.nn.Parameter(0.0*torch.ones(snn2.fc_hh.weight.shape, device=device))
snn2.test(test_loader, criterion=nn.MSELoss())

# %%
fig = snn2.plot_activity('x')

# %%
fig = snn2.plot_activity('h')

# %%
fig = snn2.plot_mem('h',[0])
